# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
a=pd.read_excel("Data_Train.xlsx")
d_test=pd.read_excel("Data_Test.xlsx")

# %%
d_test.head()
# Out:
#                                                Title                  Author  \
# 0         The Complete Sherlock Holmes: 2 Boxes sets  Sir Arthur Conan Doyle
# 1  Learn Docker - Fundamentals of Docker 18.x: Ev...     Gabriel N. Schenker
# 2                                           Big Girl          Danielle Steel
# 3  Think Python: How to Think Like a Computer Sci...         Allen B. Downey
# 4  Oxford Word Skills: Advanced - Idioms & Phrasa...           Redman Gairns
#
#                               Edition  Reviews  Ratings  \
# 0  Mass Market Paperback,– 1 Oct 1986      4.4    960.0
# 1     Paperback,– Import, 26 Apr 2018      5.0      1.0
# 2             Paperback,– 17 Mar 2011      5.0      4.0
# 3                    Paperback,– 2016      4.1     11.0
# 4             Paperback,– 26 Dec 2011      4.4      9.0
#
#                                             Synopsis  \
# 0  A collection of entire body of work of the She...
# 1  Enhance your software deployment workflow usin...
# ...

# %%
a.head()
# Out:
#                                         Title           Author  \
# 0         The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1          Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                Leviathan (Penguin Classics)    Thomas Hobbes
# 3          A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4  LIFE 70 Years of Extraordinary Photography  Editors of Life
#
#                    Edition             Reviews              Ratings  \
# 0  Paperback,– 10 Mar 2016  4.0 out of 5 stars   8 customer reviews
# 1   Paperback,– 7 Nov 2012  3.9 out of 5 stars  14 customer reviews
# 2  Paperback,– 25 Feb 1982  4.8 out of 5 stars   6 customer reviews
# 3   Paperback,– 5 Oct 2017  4.1 out of 5 stars  13 customer reviews
# 4  Hardcover,– 10 Oct 2006  5.0 out of 5 stars    1 customer review
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# ...

# %%
a.shape
# Out:
# (6237, 9)

# %%
d_test.shape
# Out:
# (1560, 8)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6237 entries, 0 to 6236
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         6237 non-null   object
#  1   Author        6237 non-null   object
#  2   Edition       6237 non-null   object
#  3   Reviews       6237 non-null   float64
#  4   Ratings       6237 non-null   float64
#  5   Synopsis      6237 non-null   object
#  6   Genre         6237 non-null   object
#  7   BookCategory  6237 non-null   object
#  8   Price         6237 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 438.7+ KB

# %%
a["Reviews"]=a.Reviews.apply(lambda r:float(r.split()[0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 a["Reviews"]=a.Reviews.apply(lambda r:float(r.split()[0]))
#       2 a["Ratings"]=a.Reviews.apply(lambda r:float(r.split()[0]))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# ...

# %%
d_test["Reviews"]=d_test.Reviews.apply(lambda r:float(r.split()[0]))

# %%
a["Ratings"].head()
# Out:
# 0     8.0
# 1    14.0
# 2     6.0
# 3    13.0
# 4     1.0
# Name: Ratings, dtype: float64

# %%
a["Ratings"]=a.Ratings.str.extract('(\d+)')
a["Ratings"]=a.Ratings.astype(float)

# %%
d_test["Ratings"]=d_test.Ratings.str.extract('(\d+)')
d_test["Ratings"]=d_test.Ratings.astype(float)

# %%
data=pd.get_dummies(a,columns=["BookCategory"])
data.head()
# Out:
#                                         Title           Author  \
# 0         The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1          Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                Leviathan (Penguin Classics)    Thomas Hobbes
# 3          A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4  LIFE 70 Years of Extraordinary Photography  Editors of Life
#
#                    Edition  Reviews  Ratings  \
# 0  Paperback,– 10 Mar 2016      4.0      8.0
# 1   Paperback,– 7 Nov 2012      3.9     14.0
# 2  Paperback,– 25 Feb 1982      4.8      6.0
# 3   Paperback,– 5 Oct 2017      4.1     13.0
# 4  Hardcover,– 10 Oct 2006      5.0      1.0
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# 2  "During the time men live without a common Pow...
# 3  A handful of grain is found in the pocket of a...
# ...

# %%
test=pd.get_dummies(a,columns=["BookCategory"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6237 entries, 0 to 6236
# Data columns (total 14 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Reviews                                            6237 non-null   float64
#  1   Ratings                                            6237 non-null   float64
#  2   Price                                              6237 non-null   float64
#  3   BookCategory_Action & Adventure                    6237 non-null   uint8
#  4   BookCategory_Arts, Film & Photography              6237 non-null   uint8
#  5   BookCategory_Biographies, Diaries & True Accounts  6237 non-null   uint8
#  6   BookCategory_Comics & Mangas                       6237 non-null   uint8
#  7   BookCategory_Computing, Internet & Digital Media   6237 non-null   uint8
#  8   BookCategory_Crime, Thriller & Mystery             6237 non-null   uint8
# ...

# %%
test.head()
# Out:
#    Reviews  Ratings   Price  BookCategory_Action & Adventure  \
# 0      4.0      8.0  220.00                                1
# 1      3.9     14.0  202.93                                0
# 2      4.8      6.0  299.00                                0
# 3      4.1     13.0  180.00                                0
# 4      5.0      1.0  965.62                                0
#
#    BookCategory_Arts, Film & Photography  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      1
#
#    BookCategory_Biographies, Diaries & True Accounts  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# ...

# %%
d_test=pd.get_dummies(d_test,columns=["BookCategory"])

# %%
d_test.head()
# Out:
#    Reviews  Ratings  BookCategory_Action & Adventure  \
# 0      4.4    960.0                                0
# 1      5.0      1.0                                0
# 2      5.0      4.0                                0
# 3      4.1     11.0                                0
# 4      4.4      9.0                                0
#
#    BookCategory_Arts, Film & Photography  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
#
#    BookCategory_Biographies, Diaries & True Accounts  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    BookCategory_Comics & Mangas  \
# ...

# %%
d_test = d_test.drop(['Title','Genre', 'Author','Synopsis','Edition'],1, inplace= False)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_14936\3894091484.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   d_test = d_test.drop(['Title','Genre', 'Author','Synopsis','Edition'],1, inplace= False)

# %%
data = data.drop(['Title','Genre', 'Author','Synopsis','Edition'],1, inplace= False)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_14936\659449508.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop(['Title','Genre', 'Author','Synopsis','Edition'],1, inplace= False)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [47], line 1
# ----> 1 data = data.drop(['Title','Genre', 'Author','Synopsis','Edition'],1, inplace= False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
test = test.drop(['Title','Genre', 'Author','Synopsis','Edition'],1, inplace= False)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_14936\642810392.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   test = test.drop(['Title','Genre', 'Author','Synopsis','Edition'],1, inplace= False)

# %%
a.describe
# Out:
# <bound method NDFrame.describe of                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
# ...

# %%
data["Price"]
# Out:
# 0       220.00
# 1       202.93
# 2       299.00
# 3       180.00
# 4       965.62
#          ...
# 6232    322.00
# 6233    421.00
# 6234    399.00
# 6235    319.00
# 6236    452.00
# Name: Price, Length: 6237, dtype: float64

# %%
y
# Out:
# array([[220.  ],
#        [202.93],
#        [299.  ],
#        ...,
#        [399.  ],
#        [319.  ],
#        [452.  ]])

# %%
y=np.array(data["Price"]).reshape(-1,1)
x=data.drop("Price",axis=1)
x.shape
# Out:
# (6237, 13)

# %%
x.head()
# Out:
#    Reviews  Ratings  BookCategory_Action & Adventure  \
# 0      4.0      8.0                                1
# 1      3.9     14.0                                0
# 2      4.8      6.0                                0
# 3      4.1     13.0                                0
# 4      5.0      1.0                                0
#
#    BookCategory_Arts, Film & Photography  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      1
#
#    BookCategory_Biographies, Diaries & True Accounts  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    BookCategory_Comics & Mangas  \
# ...

# %%
data.corr()
# Out:
#                                                     Reviews   Ratings  \
# Reviews                                            1.000000 -0.009644
# Ratings                                           -0.009644  1.000000
# Price                                              0.108373 -0.101145
# BookCategory_Action & Adventure                    0.009149 -0.003412
# BookCategory_Arts, Film & Photography              0.039866 -0.052676
# BookCategory_Biographies, Diaries & True Accounts  0.016837  0.162393
# BookCategory_Comics & Mangas                       0.092094 -0.058998
# BookCategory_Computing, Internet & Digital Media  -0.026881 -0.045564
# BookCategory_Crime, Thriller & Mystery            -0.080658  0.040833
# BookCategory_Humour                                0.026311 -0.057393
# BookCategory_Language, Linguistics & Writing      -0.057767 -0.013023
# BookCategory_Politics                             -0.013167  0.028476
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(y_train)
# Out:
# StandardScaler()

# %%
scaler.transform(y_train)
# Out:
# array([[-0.26139555],
#        [-0.53456938],
#        [ 0.03661227],
#        ...,
#        [-0.50007773],
#        [ 2.6745333 ],
#        [ 1.08515829]])

# %%
scaler.fit(x_train,y_train)
# Out:
# StandardScaler()

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4989 entries, 1907 to 3771
# Data columns (total 13 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Reviews                                            4989 non-null   float64
#  1   Ratings                                            4989 non-null   float64
#  2   BookCategory_Action & Adventure                    4989 non-null   uint8
#  3   BookCategory_Arts, Film & Photography              4989 non-null   uint8
#  4   BookCategory_Biographies, Diaries & True Accounts  4989 non-null   uint8
#  5   BookCategory_Comics & Mangas                       4989 non-null   uint8
#  6   BookCategory_Computing, Internet & Digital Media   4989 non-null   uint8
#  7   BookCategory_Crime, Thriller & Mystery             4989 non-null   uint8
#  8   BookCategory_Humour                                4989 non-null   uint8
# ...

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 4989 entries, 1907 to 3771
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 4989 non-null   float64
# dtypes: float64(1)
# memory usage: 78.0 KB

# %%
tree.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
tree.predict(x_test)
# Out:
# array([ 431.99619048,  289.97666667,  718.81546093, ..., 1282.47219752,
#         580.31918246,  878.00964838])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel

# %%
model=LinearRegression()
tree=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([673.20069865, 855.76525602, 568.11037018, ..., 536.60667094,
#        545.29948571, 809.63286024])

# %%
y_test
# Out:
# array([[ 90.  ],
#        [367.  ],
#        [573.18],
#        ...,
#        [625.  ],
#        [202.  ],
#        [599.  ]])

# %%
x_train
# Out:
#       Reviews  Ratings  BookCategory_Action & Adventure  \
# 1907      4.3      5.0                                1
# 6167      3.7    113.0                                1
# 2487      5.0      4.0                                0
# 2378      4.7     37.0                                0
# 2603      4.0     14.0                                0
# ...       ...      ...                              ...
# 5591      4.1     27.0                                0
# 1046      5.0      1.0                                0
# 4262      4.5      2.0                                0
# 3740      4.6     12.0                                0
# 3771      4.8      6.0                                0
#
#       BookCategory_Arts, Film & Photography  \
# 1907                                      0
# 6167                                      0
# 2487                                      0
# 2378                                      0
# 2603                                      1
# ...

# %%
tree.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_train.head()
# Out:
# 1907     358.0
# 6167     310.0
# 2487     369.0
# 2378     474.0
# 2603    1699.0
# Name: Price, dtype: float64

# %%
pred=tree.predict(x_train)
pred
# Out:
# array([313.74833333, 245.3868    , 485.94873333, ..., 161.4985    ,
#        923.1339583 , 925.98140476])

# %%
r2_score(y_train,pred)
# Out:
# 0.2999607691116405

# %%
data=pd.DataFrame(y_train,pred)

# %%
data
# Out:
#                   0
# 313.748333    383.0
# 245.386800    185.0
# 485.948733    599.0
# 248.323700    262.0
# 1282.472198  1200.0
# ...             ...
# 365.620198    100.0
# 299.850000    224.0
# 161.498500    210.0
# 923.133958   2511.0
# 925.981405   1359.0
#
# [4989 rows x 1 columns]

# %%
sfm = SelectFromModel(model)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PowerTransformer

# %%
power=PowerTransformer()

# %%
power.fit(x_train,y_train)
# Out:
# PowerTransformer()

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 500, random_state = 300)
regressor.fit(x_train, y_train)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_14936\3335631100.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# RandomForestRegressor(n_estimators=500, random_state=300)

# %%
y_pred = regressor.predict(x_train)
y_pred
# Out:
# array([351.766     , 215.8991381 , 524.38844   , ..., 192.97748571,
#        925.53073607, 871.99404476])

# %%
r2_score(y_train,y_pred)
# Out:
# 0.40397137471699074

# %%
ypre=regressor.predict(d_test)

# %%
ypre = pd.DataFrame(ypre)

# %%
ypre = ypre.rename(columns= {0:"Price"})

# %%
ypre.to_csv("Submission.csv")

# %%
cs=pd.read_excel("Sample_Submission.xlsx")

# %%
cs.head()
# Out:
#    Price
# 0    119
# 1    123
# 2    108
# 3    118
# 4    132
